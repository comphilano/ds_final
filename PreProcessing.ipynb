# %% [markdown]
# # PreProcessing

# %%
import re
import pandas as pd

# %%
# open

items_df = pd.read_csv('ShoppeItem.tsv', sep='\t')
pd.set_option('max_colwidth', 10000)

items_df
# Out:
#                                                                                               name  \
# 0                                                Áo Hoodies Thời Trang Dành Cho Nam (M-5Xl) 100kg)
# 1            Quần âu nam Hàn Quốc dáng ôm công sở quần tây nam vải co giãn nhẹ chống nhăn chống xù
# 2                                     Hộp 4 Sịp Đùi Boxer Thông Hơi Cao Cấp Dành Cho Nam VEIKUCOOL
# 3                      Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Động Thời Trang Cao Cấp VICERO
# 4       Bóp Ví dáng đứng Nam Da Bò Thật - Kiểu dáng nhỏ gọn, da Safiano cao cấp - thời trang OLUX.
# ..                                                                                             ...
# 976                Áo thun nam tay dài, phối màu nam tính, phong cách thời trang nam thu đông 2020
# 977                                                     Đồng hồ thời trang nam Orlando cá tính D77
# ...
