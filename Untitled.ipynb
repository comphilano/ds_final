# %%
import requests
import json
import time

# %%
newest = 0
all_items = []

# %%
###
#Get page 1 -> 13
###
i = 1
while True:
    try:
        
        url =f'https://shopee.vn/api/v2/search_items/?by=relevancy&keyword=thoi%20trang%20nam&limit=50&newest={newest}&order=desc&page_type=search&version=2'

        payload={}
        headers = {
          'authority': 'shopee.vn',
          'sec-ch-ua': '"Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"',
          'x-shopee-language': 'vi',
          'x-requested-with': 'XMLHttpRequest',
          'if-none-match-': '55b03-dceaa180c1eeddc86ba1970534386c5f',
          'sec-ch-ua-mobile': '?0',
          'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 FS',
          'x-api-source': 'pc',
          'accept': '*/*',
          'sec-fetch-site': 'same-origin',
          'sec-fetch-mode': 'cors',
          'sec-fetch-dest': 'empty',
          'referer': 'https://shopee.vn/search?keyword=thoi%20trang%20nam',
          'accept-language': 'vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5',
          'cookie': 'SPC_IA=-1; SPC_F=xy8cDlkhDlqLeCmJKA43hs8UvmvwNAdV; REC_T_ID=527dc03e-e820-11ea-af33-3c15fb3aee63; _fbp=fb.1.1598503612222.1102617144; G_ENABLED_IDPS=google; SPC_CLIENTID=xy8cDlkhDlqLeCmJrfeazpkeljwtewtt; csrftoken=uBzcFbopA2X4oZMfFC2ZxJnd0pIMfdgr; welcomePkgShown=true; _hjid=61a2a48d-3cdf-4387-8dd0-e402b2c830d9; SPC_EC=-; SPC_U=-; _gcl_au=1.1.2002568888.1609424355; _med=refer; _fbc=fb.1.1609424355495.IwAR2MCCDPf3Bd58M7moDMbDtlh_AECwYVZ1GzpVngTYY4ynpD6Vz7hXu9G5Q; SPC_SI=bfftocvn.nkCIcFHX86pnYTjYLpnhBMJZWMXw2Xt3; _gid=GA1.2.1679848950.1609554969; _ga=GA1.1.1996604151.1598503618; _ga_M32T05RVZT=GS1.1.1609575865.7.0.1609575865.0; SPC_R_T_ID="pwAurCGPx4JtDvk+bQtyUD6c4uTFZ6BSLfmWJ+qIYreJvFhePt3FHQE9uMKYIzgBrq9rC71xk0LodxzKqNnTr0kiqTZGaQ8v95I08N3Y6gY="; SPC_T_IV="zPwayjja/mNxTaJcOk129g=="; SPC_R_T_IV="zPwayjja/mNxTaJcOk129g=="; SPC_T_ID="pwAurCGPx4JtDvk+bQtyUD6c4uTFZ6BSLfmWJ+qIYreJvFhePt3FHQE9uMKYIzgBrq9rC71xk0LodxzKqNnTr0kiqTZGaQ8v95I08N3Y6gY="; SPC_R_T_ID="ZBV9lwcJvBfGFHW06oiZ8Fs38bUc3MkkZ/+g08kY0zx98XgkCpD4MGdzyhiQqAfND2qK4WRpuyHP0NIab1OWEPbwVz3a+OQ0WxxE0NQfSzA="; SPC_T_IV="xE7S3rUv8zMwHM5yEhlQEA=="; SPC_R_T_IV="xE7S3rUv8zMwHM5yEhlQEA=="; SPC_T_ID="ZBV9lwcJvBfGFHW06oiZ8Fs38bUc3MkkZ/+g08kY0zx98XgkCpD4MGdzyhiQqAfND2qK4WRpuyHP0NIab1OWEPbwVz3a+OQ0WxxE0NQfSzA="; SPC_CT_31a5d522="1609576108.BQcqCmUMjCtSaqC0muLcBk1HnJvBGfKi0WNEM63/+ig="',
          'if-none-match': 'bd6f8e1f6344de4fc9976e38feb57437'
        }

        response = requests.request("GET", url, headers=headers, data=payload)
        print(len(response.text))
        print(f'get! {i}')
        
        json_pydata = json.loads(response.text) # Shortcut: json_pydata = r.json()
        
        all_items.extend(json_pydata['items'])
        
        newest += 50
        
        time.sleep(3)
    except Exception as e:
        print(f'Error: {e}')
        break


# print(response.text)
# Out:
# 224295
# get! 1
# 198149
# get! 1
# 217390
# get! 1
# 224954
# get! 1
# 217025
# get! 1
# 226026
# get! 1
# 232838
# get! 1
# 227103
# get! 1
# 206560
# get! 1
# 210788
# get! 1
# 220080
# get! 1
# 226732
# get! 1
# 234444
# get! 1
# 225874
# get! 1
# 228993
# get! 1
# 237077
# get! 1
# 213130
# get! 1
# 211925
# get! 1
# 209930
# get! 1
# 212600
# get! 1
# 0
# get! 1
# Error: Expecting value: line 1 column 1 (char 0)

# %%
file = open("all_items.json", 'w', encoding='utf-8')
file.write(str(all_items))
# Out:
# 4698356

# %%
# %run ItemModel.ipynb
kkk = []
for item in all_items:
            itemModel = SHOPPEItem()
            itemModel.name = item['name']
            itemModel.shop_location = item['shop_location']
            itemModel.historical_sold = item['historical_sold']
            itemModel.sold = item['sold']
            itemModel.shopee_verified = item['shopee_verified']
            itemModel.discount = item['discount']
            itemModel.is_adult = item['is_adult']
            for tier_variation in item['tier_variations']:
                itemModel.options = len(tier_variation['options'])
            itemModel.show_official_shop_label_in_title = item['show_official_shop_label_in_title']
            itemModel.rating_star = item['item_rating']['rating_star']
            itemModel.rating_count = item['item_rating']['rating_count']
            itemModel.flash_sale = item['flash_sale']
            itemModel.upcoming_flash_sale = item['upcoming_flash_sale']
            itemModel.price_min = item['price_min']
            itemModel.price_min_before_discount = item['price_min_before_discount']
            
            itemModel.price_max = item['price_max']
            itemModel.price_max_before_discount = item['price_max_before_discount']
            itemModel.price = item['price']
            itemModel.price_before_discount = item['price_before_discount']
            itemModel.coin_earn_label = item['coin_earn_label']
            itemModel.liked_count = item['liked_count']
            itemModel.view_count = item['view_count']
            itemModel.cmt_count = item['cmt_count']
            itemModel.is_preferred_plus_seller = item['is_preferred_plus_seller']
            itemModel.show_free_shipping = item['show_free_shipping']
            itemModel.images = len(item['images'])
            itemModel.video_info_list = len(item['video_info_list'])
            kkk.append(itemModel)
file = open('ShoppeItem.tsv', 'w', encoding='utf-8')
 
file.write(f'name\tshop_location\tshopee_verified\tdiscount\tis_adult\t'
                + f'options\tshow_official_shop_label_in_title\trating_star\trating_count\t'
                + f'flash_sale\tupcoming_flash_sale\tprice_min\tprice_min_before_discoun\t'
                + f'price_max\tprice_max_before_discount\tprice\tprice_before_discount\t'
                + f'coin_earn_label\tliked_count\tview_count\tcmt_count\t'
                + f'is_preferred_plus_seller\tshow_free_shipping\timages\tvideo_info_list\t'
                + f'sold\thistorical_sold\n')

for item in kkk:
                file.write(f'{item.name}\t{item.shop_location}\t{item.shopee_verified}\t{item.discount}\t{item.is_adult}\t'
                + f'{item.options}\t{item.show_official_shop_label_in_title}\t{item.rating_star}\t{item.rating_count}\t'
                + f'{item.flash_sale}\t{item.upcoming_flash_sale}\t{item.price_min}\t{item.price_min_before_discount}\t'
                + f'{item.price_max}\t{item.price_max_before_discount}\t{item.price}\t{item.price_before_discount}\t'
                + f'{item.coin_earn_label}\t{item.liked_count}\t{item.view_count}\t{item.cmt_count}\t'
                + f'{item.is_preferred_plus_seller}\t{item.show_free_shipping}\t{item.images}\t{item.video_info_list}\t'
                + f'{item.sold}\t{item.historical_sold}\n')

# %%
name = [] # string
shop_location = [] # string
historical_sold = [] # numeric
sold = []
shopee_verified = [] # true false
discount = [] # numeric
is_adult = [] #true falses
options = [] # tier_variations -> options : don't name, just count how many options this item have
show_official_shop_label_in_title = [] # true false
rating_star = [] ## item_rating -> rating_star / numeric
rating_count = [] # item_rating -> rating_count / array: [all,1*,2*,3*,4*,5*]
flash_sale = []

price_min = []
price_min_before_discount = [] # 20000000000
price_max = [] # 12400000000 : 124k
price_max_before_discount = []
price = []
price_before_discount = []

coin_earn_label = []
liked_count = [] # numeric
upcoming_flash_sale = []
view_count = []
cmt_count = []
is_preferred_plus_seller = []
show_free_shipping = [] # true false

images = [] #array of string, just count how many
video_info_list = [] # array {}, just count how many videos

for item in all_items:
    name.append(item['name'])

len(name)
# Out:
# 1000

# %% [markdown]
#  "itemid": 2704231798,
#             "welcome_package_info": null,
#             "liked": false,
#             "recommendation_info": null,
#             "bundle_deal_info": null,
#             "price_max_before_discount": 20000000000,
#             "tracking_info": null,
#             "image": "6aa50c5c89453cb10b1271b33204c507",
#             "recommendation_algorithm": null,
#             "is_cc_installment_payment_eligible": false,
#             "shopid": 106856772,
#             "can_use_wholesale": false,
#             "group_buy_info": null,
#             "reference_item_id": "",
#             "currency": "VND",
#             "raw_discount": 38,
#             "show_free_shipping": true,
#             "video_info_list": [
#                 {
#                     "duration": 50,
#                     "video_id": "JzECtWv67JkOPQVz",
#                     "version": 0,
#                     "thumb_url": "ffff464380fceb2bd4653ffbf64bb9dc"
#                 }
#             ],
#             "ads_keyword": "wkdaelpmissisiht",
#             "collection_id": null,
#             "images": [
#                 "6aa50c5c89453cb10b1271b33204c507",
#                 "91e9c20f4001e95a5aab2447ac89ecf9",
#                 "79a3a9e1376477adc6eb3d4d1ab71498",
#                 "f116f6eb7a7f32ea94ef4a3a626b07a7",
#                 "7addcaa3d74d0adecb9495d27b340147",
#                 "8d2254781c78d8655167bc31a8bf979d",
#                 "527a16b735d347dcf22bcdf5c67e8cf4",
#                 "f05b7472cb628d89dbffdf01a476625b",
#                 "f982ce4dbb5a934b9249f87766279773"
#             ],
#             "is_preferred_plus_seller": false,
#             "price_before_discount": 20000000000,
#             "is_category_failed": false,
#             "show_discount": 38,
#             "cmt_count": 1559,
#             "view_count": 12775,
#             "display_name": null,
#             "catid": 78,
#             "voucher_info": null,
#             "upcoming_flash_sale": null,
#             "is_official_shop": false,
#             "brand": "No Brand",
#             "price_min": 12400000000,
#             "liked_count": 617,
#             "can_use_bundle_deal": false,
#             "show_official_shop_label": false,
#             "coin_earn_label": null,
#             "price_min_before_discount": 20000000000,
#             "cb_option": 0,
#             "sold": 512,
#             "deduction_info": "YmZmdG9jdm4ubmtDSWNGSHMvd1SaHYJrKd95Mjq9J5hhVbZiiVxpSTZexgwb0gYyqWzwWzixHR6XaCCAucJ/K0nS7FZXyibpe92Ibzl5eFfEEXhEofTjfLRoCjqwNDKEYGtvf0q3ksV9poGQrrLjQw==",
#             "stock": 20227,
#             "status": 1,
#             "price_max": 12400000000,
#             "add_on_deal_info": {
#                 "add_on_deal_id": 1758938,
#                 "add_on_deal_label": "Mua Kèm Deal Sốc",
#                 "sub_type": 0
#             },
#             "is_group_buy_item": null,
#             "flash_sale": null,
#             "price": 12400000000,
#             "shop_location": "Hà Nội",
#             "item_rating": {
#                 "rating_star": 4.851733,
#                 "rating_count": [
#                     1559,
#                     11,
#                     5,
#                     35,
#                     106,
#                     1402
#                 ],
#                 "rcount_with_image": 352,
#                 "rcount_with_context": 572
#             },
#             "show_official_shop_label_in_title": false,
#             "tier_variations": [
#                 {
#                     "images": [
#                         "f982ce4dbb5a934b9249f87766279773",
#                         "8d75552d7eebd60d31b895eb854ce2a3",
#                         "5cc125d08e23f02b4c398e0fdd7756cf",
#                         "6aa50c5c89453cb10b1271b33204c507"
#                     ],
#                     "properties": [],
#                     "type": 0,
#                     "name": "Size",
#                     "options": [
#                         "L (45-55kg)",
#                         "XL (56-65kg)",
#                         "XXL (66-85kg)",
#                         "3XL (86-95kg)"
#                     ]
#                 }
#             ],
#             "is_adult": false,
#             "discount": "38%",
#             "flag": 2,
#             "is_non_cc_installment_payment_eligible": false,
#             "has_lowest_price_guarantee": true,
#             "json_data": "CjNjOnBpZD1BO2U9YjsyLmEuMTQ3QEhJSktMTU5PUVJWWFlhYmNkZWZnaGlsbW5vcHFyczBIBHH/el35XfKaP3li71bt4SatP5ADAg==",
#             "has_group_buy_stock": null,
#             "match_type": 0,
#             "preview_info": null,
#             "welcome_package_type": 0,
#             "exclusive_price_info": null,
#             "name": "Hộp 4 Sịp Đùi Boxer Thông Hơi Cao Cấp Dành Cho Nam VEIKUCOOL",
#             "distance": null,
#             "adsid": 3867173,
#             "ctime": 1566622328,
#             "wholesale_tier_list": [],
#             "show_shopee_verified_label": true,
#             "campaignid": 843764,
#             "show_official_shop_label_in_normal_position": null,
#             "item_status": "normal",
#             "shopee_verified": true,
#             "hidden_price_display": null,
#             "size_chart": null,
#             "item_type": 0,
#             "shipping_icon_type": null,
#             "campaign_stock": null,
#             "label_ids": [
#                 1001045,
#                 1001046,
#                 1000753,
#                 1001051,
#                 1001052,
#                 1001054,
#                 1001061,
#                 1001066,
#                 1001067,
#                 1001075,
#                 1001078,
#                 1001079,
#                 1001086,
#                 1001087,
#                 1001088,
#                 1001089,
#                 1000947,
#                 1000949,
#                 1000950,
#                 1000952,
#                 1000963,
#                 1000965,
#                 1000969,
#                 1000975,
#                 1000979,
#                 1000982,
#                 1000987,
#                 1000988,
#                 1001002,
#                 1001005,
#                 1001012,
#                 1001013,
#                 1001018,
#                 1001033,
#                 1001037,
#                 1001038,
#                 1001040,
#                 1000469,
#                 1000259,
#                 1000262,
#                 1000258,
#                 1000263,
#                 1000255,
#                 1000254,
#                 1000256,
#                 1000257,
#                 1000518,
#                 1000520,
#                 1000266,
#                 1000264,
#                 1000270,
#                 1000271,
#                 1000273,
#                 1000272,
#                 1000274,
#                 1000278,
#                 1000275,
#                 1000533,
#                 1000488,
#                 1000549,
#                 1000512,
#                 1000594,
#                 1000595,
#                 1000596,
#                 1000604,
#                 1000608,
#                 1000609,
#                 1000611,
#                 1000614,
#                 1000615,
#                 1000619,
#                 1000634,
#                 1000647,
#                 1000652,
#                 1000660,
#                 1000661,
#                 1000662,
#                 1000670,
#                 1000685,
#                 1000687,
#                 1000696,
#                 1000697,
#                 1000698,
#                 1000700,
#                 1000705,
#                 1000707,
#                 1000709,
#                 1000710,
#                 1000714,
#                 1000715,
#                 1000716,
#                 1000723,
#                 1000724,
#                 1000728,
#                 1000729,
#                 1000738,
#                 1000740,
#                 1000741,
#                 1000744,
#                 1000746,
#                 1000748,
#                 1000749,
#                 1000752,
#                 1000764,
#                 1000773,
#                 1000776,
#                 1000775,
#                 1000787,
#                 1000788,
#                 1000790,
#                 1000793,
#                 1000797,
#                 1000804,
#                 1000805,
#                 1000812,
#                 1000279,
#                 1000283,
#                 1000285,
#                 1000294,
#                 1000302,
#                 1000309,
#                 1000320,
#                 1000333,
#                 1000339,
#                 1000347,
#                 1000349,
#                 1000356,
#                 1000359,
#                 1000378,
#                 1000379,
#                 1000383,
#                 1000415,
#                 1000419,
#                 1000425,
#                 1000428,
#                 1000445,
#                 1000451,
#                 1000458,
#                 1000462,
#                 1000813,
#                 1000814,
#                 1000827,
#                 1000831,
#                 1000833,
#                 1000834,
#                 1000838,
#                 1000842,
#                 1000844,
#                 1000845,
#                 1000846,
#                 1000847,
#                 1000848,
#                 1000851,
#                 1000854,
#                 1000863,
#                 1000867,
#                 1000870,
#                 1000871,
#                 1000872,
#                 1000873,
#                 1000874,
#                 1000879,
#                 1000885,
#                 1000891,
#                 1000892,
#                 1000911,
#                 1000912,
#                 1000917,
#                 1000920,
#                 1000925,
#                 1000926,
#                 1000931,
#                 1000937,
#                 1000940,
#                 1000938,
#                 1000941,
#                 1000946,
#                 1000091,
#                 1000120,
#                 1000140,
#                 1000196,
#                 1000213,
#                 1000219,
#                 1000221,
#                 1000225,
#                 1000243,
#                 1000247,
#                 44,
#                 1000260,
#                 1000265,
#                 1000267,
#                 1000268,
#                 1000269,
#                 1000276,
#                 1000277,
#                 1001321,
#                 1001324,
#                 1001249,
#                 1001248,
#                 1001351,
#                 1001352,
#                 1001353,
#                 1000355,
#                 1000412,
#                 1000455,
#                 1000558,
#                 1000560,
#                 1000600,
#                 1000643,
#                 1000732,
#                 1000735,
#                 1000743,
#                 1000901,
#                 1000921,
#                 1000951,
#                 1000956,
#                 1000957,
#                 1000966,
#                 1001030,
#                 1001060,
#                 1001323,
#                 1001388,
#                 1001398,
#                 1001399,
#                 1001390,
#                 1001043,
#                 1001409,
#                 1001419,
#                 1001418,
#                 1001420,
#                 1001421,
#                 1001440,
#                 1001597,
#                 1001693,
#                 1001711,
#                 1001748,
#                 1001791,
#                 1001790,
#                 1000967,
#                 1001837,
#                 1001857,
#                 1001903,
#                 1001925,
#                 1001948,
#                 1000742,
#                 1001959,
#                 1001961,
#                 1001968,
#                 1002071,
#                 1002098,
#                 1002100,
#                 1002105,
#                 1002120,
#                 1002129,
#                 1002139,
#                 1002148,
#                 1002182,
#                 1002181,
#                 1002229,
#                 1002261,
#                 1002263,
#                 1002278,
#                 1002282,
#                 1002296,
#                 1000062,
#                 1000112,
#                 1000138,
#                 1000139,
#                 1000205,
#                 1000315,
#                 1000317,
#                 1000352,
#                 1000464,
#                 1000530,
#                 1000531,
#                 1000532,
#                 1000570,
#                 1000586,
#                 1000588,
#                 1000593,
#                 1000632,
#                 1000675,
#                 1000719,
#                 1000761,
#                 1000779,
#                 1000795,
#                 1000829,
#                 1000836,
#                 1000899,
#                 1000906,
#                 1000930,
#                 1000942,
#                 1000960,
#                 1000962,
#                 1000972,
#                 1000986,
#                 1001050,
#                 58,
#                 1000597,
#                 1000617,
#                 1000639,
#                 1000644,
#                 1000808,
#                 1001545,
#                 1001612,
#                 1001663,
#                 1001673,
#                 1001832,
#                 1001966,
#                 1002089,
#                 1002110,
#                 1002248
#             ],
#             "service_by_shopee_flag": 0,
#             "badge_icon_type": 0,
#             "historical_sold": 4846,
#             "transparent_background_image": ""
#
# curl 'https://shopee.vn/api/v2/search_items/?by=relevancy&limit=50&match_id=78&newest=650&order=desc&page_type=search&version=2' \
#   -H 'authority: shopee.vn' \
#   -H 'sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"' \
#   -H 'x-shopee-language: vi' \
#   -H 'x-requested-with: XMLHttpRequest' \
#   -H 'if-none-match-: 55b03-43676f1f33f3f2b82e58413bf7943617' \
#   -H 'sec-ch-ua-mobile: ?0' \
#   -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 FS' \
#   -H 'x-api-source: pc' \
#   -H 'accept: */*' \
#   -H 'sec-fetch-site: same-origin' \
#   -H 'sec-fetch-mode: cors' \
#   -H 'sec-fetch-dest: empty' \
#   -H 'referer: https://shopee.vn/Th%E1%BB%9Di-Trang-Nam-cat.78?page=13' \
#   -H 'accept-language: vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5' \
#   -H 'cookie: SPC_IA=-1; SPC_F=xy8cDlkhDlqLeCmJKA43hs8UvmvwNAdV; REC_T_ID=527dc03e-e820-11ea-af33-3c15fb3aee63; _fbp=fb.1.1598503612222.1102617144; G_ENABLED_IDPS=google; SPC_CLIENTID=xy8cDlkhDlqLeCmJrfeazpkeljwtewtt; csrftoken=uBzcFbopA2X4oZMfFC2ZxJnd0pIMfdgr; welcomePkgShown=true; _hjid=61a2a48d-3cdf-4387-8dd0-e402b2c830d9; SPC_EC=-; SPC_U=-; _gcl_au=1.1.2002568888.1609424355; _med=refer; _fbc=fb.1.1609424355495.IwAR2MCCDPf3Bd58M7moDMbDtlh_AECwYVZ1GzpVngTYY4ynpD6Vz7hXu9G5Q; SPC_SI=bfftocvn.nkCIcFHX86pnYTjYLpnhBMJZWMXw2Xt3; _gid=GA1.2.1679848950.1609554969; _hjAbsoluteSessionInProgress=1; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.1.1996604151.1598503618; SPC_R_T_ID="L6k4t3xg/z8igbLCRSmnn7foxTmPUG5dZOp54+7SO/F2gmKTUTVbl0ZjbrDh3i9ZPbeochasQTKLgMOGBwHzLrhqXHZ9llr4Nb74cDHiUSM="; SPC_T_IV="bo8H0RU7TCxkVVnwhUPJdg=="; SPC_R_T_IV="bo8H0RU7TCxkVVnwhUPJdg=="; SPC_T_ID="L6k4t3xg/z8igbLCRSmnn7foxTmPUG5dZOp54+7SO/F2gmKTUTVbl0ZjbrDh3i9ZPbeochasQTKLgMOGBwHzLrhqXHZ9llr4Nb74cDHiUSM="; SPC_CT_36f93748="1609565397.8lF0Vw8O/SnZ328+r+EKpSevXBlHMhiEuoZXEYHjDdNpSWFLBH4sNEfQZju+1+eP"; _ga_M32T05RVZT=GS1.1.1609563674.6.1.1609565407.0' \
#   -H 'if-none-match: a40d6bdb074b9e7547ce63b56cc43cb3' \
#   --compressed
#
# curl 'https://shopee.vn/api/v2/search_items/?by=relevancy&limit=50&match_id=78&newest=700&order=desc&page_type=search&version=2' \
#   -H 'authority: shopee.vn' \
#   -H 'sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"' \
#   -H 'x-shopee-language: vi' \
#   -H 'x-requested-with: XMLHttpRequest' \
#   -H 'if-none-match-: 55b03-c0e0d1538dba8e60f51f5294cc17ff0b' \
#   -H 'sec-ch-ua-mobile: ?0' \
#   -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 FS' \
#   -H 'x-api-source: pc' \
#   -H 'accept: */*' \
#   -H 'sec-fetch-site: same-origin' \
#   -H 'sec-fetch-mode: cors' \
#   -H 'sec-fetch-dest: empty' \
#   -H 'referer: https://shopee.vn/Th%E1%BB%9Di-Trang-Nam-cat.78?page=14' \
#   -H 'accept-language: vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5' \
#   -H 'cookie: SPC_IA=-1; SPC_F=xy8cDlkhDlqLeCmJKA43hs8UvmvwNAdV; REC_T_ID=527dc03e-e820-11ea-af33-3c15fb3aee63; _fbp=fb.1.1598503612222.1102617144; G_ENABLED_IDPS=google; SPC_CLIENTID=xy8cDlkhDlqLeCmJrfeazpkeljwtewtt; csrftoken=uBzcFbopA2X4oZMfFC2ZxJnd0pIMfdgr; welcomePkgShown=true; _hjid=61a2a48d-3cdf-4387-8dd0-e402b2c830d9; SPC_EC=-; SPC_U=-; _gcl_au=1.1.2002568888.1609424355; _med=refer; _fbc=fb.1.1609424355495.IwAR2MCCDPf3Bd58M7moDMbDtlh_AECwYVZ1GzpVngTYY4ynpD6Vz7hXu9G5Q; SPC_SI=bfftocvn.nkCIcFHX86pnYTjYLpnhBMJZWMXw2Xt3; _gid=GA1.2.1679848950.1609554969; _hjAbsoluteSessionInProgress=1; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.1.1996604151.1598503618; SPC_R_T_ID="2ubSpc4DJnvEKpMqxovvZFFD2FVy01F3mH/h2IgvrUhFmsPftg39rPs+RKJfrmHt+s6VWtmtA5X1JPNhvqW0h0KekNzFZnoAxDugdKVs2UY="; SPC_T_IV="Qux0fA4Et9ATOhkQWQxj4w=="; SPC_R_T_IV="Qux0fA4Et9ATOhkQWQxj4w=="; SPC_T_ID="2ubSpc4DJnvEKpMqxovvZFFD2FVy01F3mH/h2IgvrUhFmsPftg39rPs+RKJfrmHt+s6VWtmtA5X1JPNhvqW0h0KekNzFZnoAxDugdKVs2UY="; SPC_CT_36f93748=1609566004.sic1qG+J0pjPDTWcFcQMJATNIIyxgda3Hq60jZzWk3nNUwzLVoo+HsttvQT69QGX; _ga_M32T05RVZT=GS1.1.1609563674.6.1.1609566023.0' \
#   -H 'if-none-match: 43b05e38e39429825a34b92ad260e2b3' \
#   --compressed
#
# curl 'https://shopee.vn/api/v2/search_items/?by=relevancy&limit=50&match_id=78&newest=750&order=desc&page_type=search&version=2' \
#   -H 'authority: shopee.vn' \
#   -H 'sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"' \
#   -H 'x-shopee-language: vi' \
#   -H 'x-requested-with: XMLHttpRequest' \
#   -H 'if-none-match-: 55b03-e91c5e6e7d20928ea6834afda08fe8ef' \
#   -H 'sec-ch-ua-mobile: ?0' \
#   -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 FS' \
#   -H 'x-api-source: pc' \
#   -H 'accept: */*' \
#   -H 'sec-fetch-site: same-origin' \
#   -H 'sec-fetch-mode: cors' \
#   -H 'sec-fetch-dest: empty' \
#   -H 'referer: https://shopee.vn/Th%E1%BB%9Di-Trang-Nam-cat.78?page=15' \
#   -H 'accept-language: vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5' \
#   -H 'cookie: SPC_IA=-1; SPC_F=xy8cDlkhDlqLeCmJKA43hs8UvmvwNAdV; REC_T_ID=527dc03e-e820-11ea-af33-3c15fb3aee63; _fbp=fb.1.1598503612222.1102617144; G_ENABLED_IDPS=google; SPC_CLIENTID=xy8cDlkhDlqLeCmJrfeazpkeljwtewtt; csrftoken=uBzcFbopA2X4oZMfFC2ZxJnd0pIMfdgr; welcomePkgShown=true; _hjid=61a2a48d-3cdf-4387-8dd0-e402b2c830d9; SPC_EC=-; SPC_U=-; _gcl_au=1.1.2002568888.1609424355; _med=refer; _fbc=fb.1.1609424355495.IwAR2MCCDPf3Bd58M7moDMbDtlh_AECwYVZ1GzpVngTYY4ynpD6Vz7hXu9G5Q; SPC_SI=bfftocvn.nkCIcFHX86pnYTjYLpnhBMJZWMXw2Xt3; _gid=GA1.2.1679848950.1609554969; _hjAbsoluteSessionInProgress=1; AMP_TOKEN=%24NOT_FOUND; SPC_R_T_ID="EW4OSxnvrB1Q7tiK3SRtbk/oXey3bkM8num6+kj64TgbWfPCWit/euUSEsYlnM+kkChWW16gZnRmkR2o+B1wIJeY+OUKszXeYziJ0IwKvP0="; SPC_T_IV="50CwQWyEvPmffLuKfUjSmA=="; SPC_R_T_IV="50CwQWyEvPmffLuKfUjSmA=="; SPC_T_ID="EW4OSxnvrB1Q7tiK3SRtbk/oXey3bkM8num6+kj64TgbWfPCWit/euUSEsYlnM+kkChWW16gZnRmkR2o+B1wIJeY+OUKszXeYziJ0IwKvP0="; SPC_CT_36f93748=1609566100.5ABNXokdupzP34S03N1Dt5NAaYB31AD4qYNFZ+WLGZyt2eI5QnHfWcVbLgamTQcA; _ga=GA1.1.1996604151.1598503618; _ga_M32T05RVZT=GS1.1.1609563674.6.1.1609566101.0' \
#   -H 'if-none-match: d52128a23d2c6a4afd5dd5766d10e8a0' \
#   --compressed
